# %%
import os
import sys
import gzip
import time
import pickle
import subprocess
import pyfastx
import gzip
import pandas as pd
import multiprocessing 
from multiprocessing import Pool

df = pd.read_csv('/root/wangje/Project/Yin/Script/p5_barcode.txt', sep='\t')
def Extract_UMI_Barcode(Read1):
    # 开始时间
    time_start = time.time()
    fa = pyfastx.Fastx(Read1)
    test_list = []
    all_seq_list = []
    pattern_seq = []
    one_barcode_list = []
    no_barcode_list = []
    tag = []
    for name, seq, comment in fa:
        all_seq_list.append(seq)
        len_all_seq_list = len(all_seq_list)
        if 'CAGAGC' in seq:
            pattern_seq.append(seq)
            len_pattern_seq = len(pattern_seq)
            # 一般情况下umi系列是靠近序列的5‘端，不需要考虑多匹配
            # print(seq.find('CAGAGC'))
            umi_index = int(seq.find('CAGAGC'))
            # print(seq[int(umi_index+6+8): int(umi_index+6+18)] == 'TCCTACCAGT')
            # 检测是否同时包含barcode1和barcode2
            # print(seq)
            # if df.loc[:,'barcode2'].str.contains(seq[int(umi_index+6+8): int(umi_index+6+18)]).any() and df.loc[:,'barcode1'].str.contains(seq[int(umi_index-10): int(umi_index)]).any():
            barcode1 = seq[int(umi_index-10):int(umi_index)]
            barcode2 = seq[int(umi_index+6+8): int(umi_index+6+18)]
            # print(barcode1)
            # print(barcode2)
            if barcode1 in df.loc[:, 'barcode1'].values and barcode2 in df.loc[:, 'barcode2'].values:
                test_list.append(seq)
                tag.append(name)
            elif barcode1 in df.loc[:, 'barcode1'].values or barcode2 in df.loc[:, 'barcode2'].values:
                one_barcode_list.append(seq)
            else:
                no_barcode_list.append(seq)
            # print(seq)
    time_end = time.time()
    time_sum = time_end - time_start
    print("""
          ---------------- tmp introduce ---------------------
          file: %s
          UMI---->>>
          UMI完全匹配序列数目: %s
          全部的序列数目: %s
          未匹配的序列数目: %s
          UMI+barcode---->>>
          两个barcode和UMI均匹配数目:%s
          其中一个barcode匹配的数目:%s
          barcode没有匹配的数目: %s
          耗时: %s s
          """ % (Read1, len_pattern_seq, len_all_seq_list, str(len_all_seq_list - len_pattern_seq), len(test_list), len(one_barcode_list), len(no_barcode_list), time_sum))
if __name__ == '__main__':
    # for file1 in os.listdir('/root/wangje/Project/Yin/E100067938-中山大学孙逸仙纪念医院/'):
    #     if file1.endswith('1.fq.gz'):
    #         # print(os.path.join('/root/wangje/Project/E150001464-中山大学孙逸仙纪念医院/',file))
    #         sub_process = multiprocessing.Process(target=Extract_UMI_Barcode,kwargs={'Read1':f"{os.path.join('/root/wangje/Project/Yin/E100067938-中山大学孙逸仙纪念医院/',file1)}"})
    #         sub_process.start()
    file = [os.path.join('/root/wangje/Project/Yin/E100067938-中山大学孙逸仙纪念医院/',x) for x in os.listdir('/root/wangje/Project/Yin/E100067938-中山大学孙逸仙纪念医院/') if x.endswith('1.fq.gz')]
    pool = Pool(processes=12)
    results = pool.map(Extract_UMI_Barcode, file)
    pool.close()
    pool.join()
    print(results)
# Out:
#           ---------------- tmp introduce ---------------------
#           file: /root/wangje/Project/Yin/E100067938-中山大学孙逸仙纪念医院/I230303_I230303-2_1.fq.gz
#           UMI---->>>
#           UMI完全匹配序列数目: 1644516
#           全部的序列数目: 1973597
#           未匹配的序列数目: 329081
#           UMI+barcode---->>>
#           两个barcode和UMI均匹配数目:1512020
#           其中一个barcode匹配的数目:111250
#           barcode没有匹配的数目: 21246
#           耗时: 709.4896106719971 s
#
#
#           ---------------- tmp introduce ---------------------
#           file: /root/wangje/Project/Yin/E100067938-中山大学孙逸仙纪念医院/I230303_I230303-6_1.fq.gz
#           UMI---->>>
#           UMI完全匹配序列数目: 1782418
#           全部的序列数目: 2167749
#           未匹配的序列数目: 385331
#           UMI+barcode---->>>
#           两个barcode和UMI均匹配数目:1635986
#           其中一个barcode匹配的数目:120946
#           barcode没有匹配的数目: 25486
#           耗时: 713.2089853286743 s
#
#
#           ---------------- tmp introduce ---------------------
#           file: /root/wangje/Project/Yin/E100067938-中山大学孙逸仙纪念医院/I230303_I230303-10_1.fq.gz
#           UMI---->>>
#           UMI完全匹配序列数目: 1825325
#           全部的序列数目: 2234715
#           未匹配的序列数目: 409390
#           UMI+barcode---->>>
#           两个barcode和UMI均匹配数目:1671157
#           其中一个barcode匹配的数目:127899
#           barcode没有匹配的数目: 26269
#           耗时: 721.0147943496704 s
#
#
#           ---------------- tmp introduce ---------------------
#           file: /root/wangje/Project/Yin/E100067938-中山大学孙逸仙纪念医院/I230303_I230303-1_1.fq.gz
#           UMI---->>>
#           UMI完全匹配序列数目: 1845483
#           全部的序列数目: 2269567
#           未匹配的序列数目: 424084
#           UMI+barcode---->>>
#           两个barcode和UMI均匹配数目:1689100
#           其中一个barcode匹配的数目:128755
#           barcode没有匹配的数目: 27628
#           耗时: 722.5918695926666 s
#
#
#           ---------------- tmp introduce ---------------------
#           file: /root/wangje/Project/Yin/E100067938-中山大学孙逸仙纪念医院/I230303_I230303-8_1.fq.gz
#           UMI---->>>
#           UMI完全匹配序列数目: 2001979
#           全部的序列数目: 2462755
#           未匹配的序列数目: 460776
#           UMI+barcode---->>>
#           两个barcode和UMI均匹配数目:1829296
#           其中一个barcode匹配的数目:144124
#           barcode没有匹配的数目: 28559
#           耗时: 725.120748758316 s
#
#
#           ---------------- tmp introduce ---------------------
#           file: /root/wangje/Project/Yin/E100067938-中山大学孙逸仙纪念医院/I230303_I230303-12_1.fq.gz
#           UMI---->>>
#           UMI完全匹配序列数目: 1889953
#           全部的序列数目: 2333664
#           未匹配的序列数目: 443711
#           UMI+barcode---->>>
#           两个barcode和UMI均匹配数目:1725351
#           其中一个barcode匹配的数目:136861
#           barcode没有匹配的数目: 27741
#           耗时: 728.6907534599304 s
#
#
#           ---------------- tmp introduce ---------------------
#           file: /root/wangje/Project/Yin/E100067938-中山大学孙逸仙纪念医院/I230303_I230303-7_1.fq.gz
#           UMI---->>>
#           UMI完全匹配序列数目: 2038748
#           全部的序列数目: 2501909
#           未匹配的序列数目: 463161
#           UMI+barcode---->>>
#           两个barcode和UMI均匹配数目:1868280
#           其中一个barcode匹配的数目:139438
#           barcode没有匹配的数目: 31030
#           耗时: 731.6942262649536 s
#
#
#           ---------------- tmp introduce ---------------------
#           file: /root/wangje/Project/Yin/E100067938-中山大学孙逸仙纪念医院/I230303_I230303-9_1.fq.gz
#           UMI---->>>
#           UMI完全匹配序列数目: 2030719
#           全部的序列数目: 2491494
#           未匹配的序列数目: 460775
#           UMI+barcode---->>>
#           两个barcode和UMI均匹配数目:1863991
#           其中一个barcode匹配的数目:137330
#           barcode没有匹配的数目: 29398
#           耗时: 734.9244661331177 s
#
#
#           ---------------- tmp introduce ---------------------
#           file: /root/wangje/Project/Yin/E100067938-中山大学孙逸仙纪念医院/I230303_I230303-4_1.fq.gz
#           UMI---->>>
#           UMI完全匹配序列数目: 2181825
#           全部的序列数目: 2645744
#           未匹配的序列数目: 463919
#           UMI+barcode---->>>
#           两个barcode和UMI均匹配数目:2003745
#           其中一个barcode匹配的数目:148119
#           barcode没有匹配的数目: 29961
#           耗时: 735.9261240959167 s
#
#
#           ---------------- tmp introduce ---------------------
#           file: /root/wangje/Project/Yin/E100067938-中山大学孙逸仙纪念医院/I230303_I230303-5_1.fq.gz
#           UMI---->>>
#           UMI完全匹配序列数目: 2066508
#           全部的序列数目: 2557125
#           未匹配的序列数目: 490617
#           UMI+barcode---->>>
#           两个barcode和UMI均匹配数目:1889368
#           其中一个barcode匹配的数目:144860
#           barcode没有匹配的数目: 32280
#           耗时: 736.6362402439117 s
#
#
#           ---------------- tmp introduce ---------------------
#           file: /root/wangje/Project/Yin/E100067938-中山大学孙逸仙纪念医院/I230303_I230303-11_1.fq.gz
#           UMI---->>>
#           UMI完全匹配序列数目: 2124525
#           全部的序列数目: 2622429
#           未匹配的序列数目: 497904
#           UMI+barcode---->>>
#           两个barcode和UMI均匹配数目:1945169
#           其中一个barcode匹配的数目:148038
#           barcode没有匹配的数目: 31318
#           耗时: 738.17942070961 s
#
#
#           ---------------- tmp introduce ---------------------
#           file: /root/wangje/Project/Yin/E100067938-中山大学孙逸仙纪念医院/I230303_I230303-3_1.fq.gz
#           UMI---->>>
#           UMI完全匹配序列数目: 2413240
#           全部的序列数目: 3050989
#           未匹配的序列数目: 637749
#           UMI+barcode---->>>
#           两个barcode和UMI均匹配数目:2209390
#           其中一个barcode匹配的数目:166997
#           barcode没有匹配的数目: 36853
#           耗时: 751.9849443435669 s
#
# [None, None, None, None, None, None, None, None, None, None, None, None]

# %%
os.cpu_count()
# Out:
# 208
